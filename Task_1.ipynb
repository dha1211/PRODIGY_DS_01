# %% [markdown]
# # Task 01

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # read csv file

# %%
df=pd.read_csv("worldpopulationdata.csv")

# %% [markdown]
# # data analysis

# %%
df.head(5)
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %%
df.tail(5)
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2022       2021       2020  \
# 1080  Virgin Islands (U.S.)          VIR  46.613382  46.764444  46.914637
# 1081     West Bank and Gaza          PSE  49.893678  49.877839  49.858957
# 1082            Yemen, Rep.          YEM  50.519031  50.538516  50.554317
# 1083                 Zambia          ZMB  49.344602  49.344951  49.338301
# 1084               Zimbabwe          ZWE  47.214139  47.167153  47.130679
#
#            2019       2018       2017  ...       2010       2009       2008  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %%
df.describe()
# Out:
#                2022          2021          2020          2019          2018  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.461378e+07  1.449711e+07  1.437307e+07  1.422876e+07  1.407966e+07
# std    7.832944e+07  7.801505e+07  7.763257e+07  7.712985e+07  7.657562e+07
# min    2.749000e+01  2.732503e+01  2.735104e+01  2.676295e+01  2.573928e+01
# 25%    5.034029e+01  5.035172e+01  5.034171e+01  5.033040e+01  5.033917e+01
# 50%    1.465500e+05  1.463660e+05  1.461650e+05  1.459570e+05  1.457520e+05
# 75%    5.903468e+06  5.856733e+06  5.831404e+06  5.814422e+06  5.774185e+06
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.392568e+07  1.376711e+07  1.360705e+07  1.344625e+07  1.328368e+07
# ...

# %% [markdown]
# # checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# checking for null values

# %%
df.isna().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# # check for unique values

# %%
print(df['Country Name'].unique())
print("\n Total no. of unique countries:"  , df['Country Name'].nunique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
# ...

# %%
print(df['Country Code'].unique())
print("\n Total no. of unique countries:"  , df['Country Code'].nunique())
# Out:
# ['AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT'
#  'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL'
#  'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN'
#  'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV'
#  'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV'
#  'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB'
#  'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY'
#  'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG' 'MWI'
#  'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG'
#  'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC' 'NER'
#  'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER' 'PHL'
# ...

# %% [markdown]
# # drop unnecessary data

# %%
df.drop(['Series Name'],axis=1,inplace=True)

# %%
df
# Out:
#             Series Code           Country Name Country Code          2022  \
# 0           SP.POP.TOTL            Afghanistan          AFG  4.112877e+07
# 1           SP.POP.TOTL                Albania          ALB  2.775634e+06
# 2           SP.POP.TOTL                Algeria          DZA  4.490322e+07
# 3           SP.POP.TOTL         American Samoa          ASM  4.427300e+04
# 4           SP.POP.TOTL                Andorra          AND  7.982400e+04
# ...                 ...                    ...          ...           ...
# 1080  SP.POP.TOTL.MA.ZS  Virgin Islands (U.S.)          VIR  4.661338e+01
# 1081  SP.POP.TOTL.MA.ZS     West Bank and Gaza          PSE  4.989368e+01
# 1082  SP.POP.TOTL.MA.ZS            Yemen, Rep.          YEM  5.051903e+01
# 1083  SP.POP.TOTL.MA.ZS                 Zambia          ZMB  4.934460e+01
# 1084  SP.POP.TOTL.MA.ZS               Zimbabwe          ZWE  4.721414e+01
#
#               2021          2020          2019          2018          2017  \
# ...

# %% [markdown]
# # top 10 countries for year 2022

# %%
#filter data for total population
total_pop_data=df[df['Series Code']=='SP.POP.TOTL']

#sort data based on the population for 2023
sorted_population=total_pop_data.sort_values(by='2022',ascending=False)

#top 10 countries with highest population for 2023
top_10_countries=sorted_population.head(10)
print(f"Top 10 countries of total population \n{top_10_countries[['Country Name']]}")
# Out:
# Top 10 countries of total population
#            Country Name
# 89                India
# 41                China
# 206       United States
# 90            Indonesia
# 149            Pakistan
# 144             Nigeria
# 26               Brazil
# 15           Bangladesh
# 161  Russian Federation
# 127              Mexico

# %% [markdown]
# # bottom 10 countries for year 2022

# %%
#filter data for total population
total_pop_data=df[df['Series Code']=='SP.POP.TOTL']

#sort data based on the population for 2022
sorted_population=total_pop_data.sort_values(by="2022",ascending=False)

#bottom 10 countries with lowest population for 2022
bottom_10_countries=sorted_population.tail(10)
print(f"Bottom 10 countries of total population \n {bottom_10_countries[['Country Name']]}")
# Out:
# Bottom 10 countries of total population
#                   Country Name
# 124          Marshall Islands
# 114             Liechtenstein
# 130                    Monaco
# 164                San Marino
# 75                  Gibraltar
# 183  St. Martin (French part)
# 27     British Virgin Islands
# 150                     Palau
# 137                     Nauru
# 201                    Tuvalu

# %% [markdown]
# # top 10 countries for year 2020

# %%
#filter data for total population
total_pop_data=df[df['Series Code']=='SP.POP.TOTL']

#sort data based on the population for 2023
sorted_population=total_pop_data.sort_values(by="2020",ascending=False)

#top 10 countries with highest population for 2020
top_10_countries=sorted_population.head(10)
print(f"Top 10 countries of total population\n {top_10_countries[['Country Name']]}")
# Out:
# Top 10 countries of total population
#             Country Name
# 41                China
# 89                India
# 206       United States
# 90            Indonesia
# 149            Pakistan
# 26               Brazil
# 144             Nigeria
# 15           Bangladesh
# 161  Russian Federation
# 98                Japan

# %% [markdown]
# # bottom 10 countries for year 2020

# %%
#filter data for total population
total_pop_data=df[df['Series Code']=='SP.POP.TOTL']

#sort data based on the population for 2020
sorted_population=total_pop_data.sort_values(by="2020",ascending=False)

#bottom 10 countries with lowest population for 2020
bottom_10_countries=sorted_population.tail(10)
print(f"Bottom 10 countries of total population\n {bottom_10_countries[['Country Name']]}")
# Out:
# Bottom 10 countries of total population
#                    Country Name
# 172  Sint Maarten (Dutch part)
# 114              Liechtenstein
# 130                     Monaco
# 164                 San Marino
# 75                   Gibraltar
# 183   St. Martin (French part)
# 27      British Virgin Islands
# 150                      Palau
# 137                      Nauru
# 201                     Tuvalu

# %% [markdown]
# # bar plot for top 10 countries for year 2022 and 2020

# %%
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2022",y="Country Code", data=top_10_countries,palette="coolwarm")
plt.title("Top 10 countries of total population (2022)",fontsize=10)
plt.xlabel("Total population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(2,2,2)
sns.barplot(x="2020",y="Country Code", data=top_10_countries,palette="coolwarm")
plt.title("Top 10 countries of total population (2020)",fontsize=10)
plt.xlabel("Total population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\dhair\AppData\Local\Temp\ipykernel_16200\1390834021.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2022",y="Country Code", data=top_10_countries,palette="coolwarm")
# C:\Users\dhair\AppData\Local\Temp\ipykernel_16200\1390834021.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code", data=top_10_countries,palette="coolwarm")

# %% [markdown]
# # bar plot for bottom 10 countries for year 2022 and 2020

# %%
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2022",y="Country Code", data=bottom_10_countries,palette="coolwarm")
plt.title("Bottom 10 countries of total population (2022)",fontsize=10)
plt.xlabel("Total population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2020",y="Country Code", data=bottom_10_countries,palette="coolwarm")
plt.title("Bottom 10 countries of total population (2020)",fontsize=10)
plt.xlabel("Total population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\dhair\AppData\Local\Temp\ipykernel_16200\324646853.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2022",y="Country Code", data=bottom_10_countries,palette="coolwarm")
# C:\Users\dhair\AppData\Local\Temp\ipykernel_16200\324646853.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code", data=bottom_10_countries,palette="coolwarm")

# %% [markdown]
# # countries with highest male population

# %%
male_population_data=df[df['Series Code']=='SP.POP.TOTL.MA.IN']
sorted_male_population=male_population_data.sort_values(by="2022",ascending=False)
male_top_10_countries=sorted_male_population.head(10)
print(f"Top 10 countries of male population\n {male_top_10_countries[['Country Name']]}")
# Out:
# Top 10 countries of male population
#             Country Name
# 523               India
# 475               China
# 640       United States
# 524           Indonesia
# 583            Pakistan
# 578             Nigeria
# 460              Brazil
# 449          Bangladesh
# 595  Russian Federation
# 561              Mexico

# %% [markdown]
# # countries with highest female population

# %%
female_population_data=df[df['Series Code']=='SP.POP.TOTL.FE.IN']
sorted_female_population=female_population_data.sort_values(by="2022",ascending=False)
female_top_10_countries=sorted_female_population.head(10)
print(f"Top 10 countries of female population\n {female_top_10_countries[['Country Name']]}")
# Out:
# Top 10 countries of female population
#             Country Name
# 258               China
# 306               India
# 423       United States
# 307           Indonesia
# 366            Pakistan
# 243              Brazil
# 361             Nigeria
# 232          Bangladesh
# 378  Russian Federation
# 344              Mexico

# %% [markdown]
# # top 10 countries with highest male and female population

# %%
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2022",y="Country Code", data=male_top_10_countries,palette="viridis")
plt.title("Top 10 countries with highest male population(2022)",fontsize=10)
plt.xlabel("Male population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x="2020",y="Country Code", data=female_top_10_countries,palette="viridis")
plt.title("Top 10 countries with highest female population(2022)",fontsize=10)
plt.xlabel("Female population",fontsize=10)
plt.ylabel("Country",fontsize=10)
plt.show()
# Out:
# C:\Users\dhair\AppData\Local\Temp\ipykernel_16200\3024831439.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2022",y="Country Code", data=male_top_10_countries,palette="viridis")
# C:\Users\dhair\AppData\Local\Temp\ipykernel_16200\3024831439.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code", data=female_top_10_countries,palette="viridis")

# %% [markdown]
# # stacked bar plot

# %% [markdown]
# # top 10 countries with highest male and female population

# %%
merge_data=pd.merge(male_population_data,female_population_data,on="Country Code",suffixes=("_male","_female"))

# %%
merge_data["Total Population"]=merge_data["2022_male"]+merge_data["2022_female"]

# %%
merge_data.head()
# Out:
#     Series Code_male Country Name_male Country Code   2022_male   2021_male  \
# 0  SP.POP.TOTL.MA.IN       Afghanistan          AFG  20766442.0  20254878.0
# 1  SP.POP.TOTL.MA.IN           Albania          ALB   1384548.0   1404454.0
# 2  SP.POP.TOTL.MA.IN           Algeria          DZA  22862237.0  22497244.0
# 3  SP.POP.TOTL.MA.IN    American Samoa          ASM     21873.0     22289.0
# 4  SP.POP.TOTL.MA.IN           Andorra          AND     40786.0     40361.0
#
#     2020_male   2019_male   2018_male   2017_male   2016_male  ...  \
# 0  19692301.0  19090409.0  18549862.0  18028696.0  17520861.0  ...
# 1   1419264.0   1428828.0   1435881.0   1440219.0   1442176.0  ...
# 2  22132899.0  21756903.0  21362603.0  20961313.0  20556314.0  ...
# 3     22921.0     23535.0     24134.0     24701.0     25240.0  ...
# 4     39615.0     38842.0     38071.0     37380.0     36628.0  ...
#
#    2009_female  2008_female  2007_female  2006_female  2005_female  \
# ...

# %%
sorted_data=merge_data.sort_values(by="Total Population",ascending=False)

# %%
top_10_countries=sorted_data.head(10)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code",y="2022_female",data=top_10_countries,color="orange",label="female population")
sns.barplot(x="Country Code",y="2022_female",data=top_10_countries,bottom=top_10_countries["2022_female"],color="green",label="male population")
plt.xlabel("Country")
plt.ylabel("population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()

# %% [markdown]
# # bottom 10 countries

# %%
bottom_10_countries=sorted_data.tail(10)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code",y="2022_female",data=bottom_10_countries,color="orange",label="female population")
sns.barplot(x="Country Code",y="2022_female",data=bottom_10_countries,bottom=bottom_10_countries["2022_female"],color="green",label="male population")
plt.xlabel("Country")
plt.ylabel("population")
plt.legend()
plt.xticks(rotation=45,ha="right")
plt.show()
